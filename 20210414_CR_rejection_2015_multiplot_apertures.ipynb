# %% [markdown]
# # import packages

# %%
from __future__ import print_function
import pandas as pd
import numpy as np
import glob
import re
import os
import sys
import astroscrappy
from astropy.io import fits
#sys.path.remove('/Users/gks/Dropbox/mypylib')
import astropy
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import astropy.io.fits 

from astropy.io import fits
from astropy.wcs import WCS
from astropy.stats import sigma_clipped_stats
from photutils import DAOStarFinder
from astropy.visualization import SqrtStretch
from astropy.visualization.mpl_normalize import ImageNormalize
from photutils import CircularAperture, CircularAnnulus

# %%
sys.path.append('src/')
import filepath
import utils
filepath, utils
# Out:
# C:\Users\Marissa\AppData\Local\Programs\Python\Python38\lib\site-packages\pysynphot\locations.py:46: UserWarning: PYSYN_CDBS is undefined; functionality will be SEVERELY crippled.
#   warnings.warn("PYSYN_CDBS is undefined; functionality will be SEVERELY "
# C:\Users\Marissa\AppData\Local\Programs\Python\Python38\lib\site-packages\pysynphot\locations.py:345: UserWarning: Extinction files not found in extinction
#   warnings.warn('Extinction files not found in %s' % (extdir, ))
# C:\Users\Marissa\AppData\Local\Programs\Python\Python38\lib\site-packages\pysynphot\refs.py:117: UserWarning: No graph or component tables found; functionality will be SEVERELY crippled. No files found for https://ssb.stsci.edu/trds\mtab\*_tmg.fits
#   warnings.warn('No graph or component tables found; '
# C:\Users\Marissa\AppData\Local\Programs\Python\Python38\lib\site-packages\pysynphot\refs.py:124: UserWarning: No thermal tables found, no thermal calculations can be performed. No files found for https://ssb.stsci.edu/trds\mtab\*_tmt.fits
#   warnings.warn('No thermal tables found, '
# (<module 'filepath' from 'src\\filepath.py'>,
#  <module 'utils' from 'src\\utils.py'>)

# %%
class FitsImage(object):
    """
    A helper class when reading fits files. Depends on pyFits.
    """
    DIRLOC = ''
    def __init__(self,filename=None,data=None,header=None,imgnumber=0):
        if filename!=None:
            self.filename = filename
            self.hdulist = fits.open(self.filename)
            self.header = self.hdulist[imgnumber].header
            data = self.hdulist[imgnumber].data
            self.data = data.astype(float)
        else:
            self.filename = ""
            self.hdulist = None
            self.header = header
            self.data = data
    
    def remove_cosmics(self,
                       verbose=True,
                       fsmode='convolve',
                       save_cleaned=False,
                       savefolder=None,
                       save_suffix="_cleaned",
                       overwrite=False,
                       gain=1.,
                       psffwhm=16.,
                       psfsize=16,
                       sigclip=6.,
                       sigfrac=0.3,
                       objlim=5.,
                       psfmodel="gauss",
                       pssl=0.,
                       cleantype="medmask",
                       **cosmics_kwargs):
        """
        Remove cosmic rays with astroscrappy
        
        Main thing is to study how the results change with the different settings.
        
        Main parameters are: GAIN and psffwhm
        """
        if verbose: print("Cleaning cosmic rays")
        self.cosmics_mask, self.cosmics_cleaned_data = astroscrappy.detect_cosmics(self.data,
                                                                                   objlim=objlim,
                                                                                   sigfrac=sigfrac,
                                                                                   sigclip=sigclip,
                                                                                   psfsize=psfsize,
                                                                                   verbose=verbose,
                                                                                   gain=gain,
                                                                                   psffwhm=psffwhm,
                                                                                   fsmode=fsmode,
                                                                                   psfmodel=psfmodel,
                                                                                   pssl=pssl,
                                                                                   cleantype=cleantype,
                                                                                   **cosmics_kwargs)
        if save_cleaned:
            # Saving file
            fp = filepath.FilePath(self.filename)
            make_dir(savefolder)
            if savefolder is not None: 
                fp.directory = savefolder
            fp.add_suffix(save_suffix)
            self.cosmics_save_filename = fp._fullpath
            self.savefits(filename=self.cosmics_save_filename,
                          data=self.cosmics_cleaned_data.astype(np.int32),
                          verbose=verbose,
                          overwrite=overwrite)
    
    def savefits(self,data=None,filename="",suffix="",verbose=True,overwrite=True):
        if data is None:
            data = self.data
        if filename=="":
            fp = filepath.Filepath(self.filename)
            if suffix=="":
                suffix = "_out"
            fp.add_suffix(suffix)
            filename=fp._fullpath
        self.header["BITPIX"]=16
        self.header["BSCALE"]=1
        self.header["BZERO"]=32768
        fits.writeto(filename,
                     data=data,
                     header=self.header,
                     overwrite=overwrite,
                     output_verify="warn")
        if verbose: print("Saved to",filename)
            
def make_dir(dirname,verbose=True):
    """    Make a directory    """
    try:
        os.makedirs(dirname)
        if verbose==True: print("Created folder:",dirname)
    except OSError:
        if verbose==True: print(dirname,"already exists. Skipping")

# %% [markdown]
# # Find all of the files to clean

# %%
FOLDERNAME = os.path.abspath(r'''C:\Users\Marissa\Desktop\Research\Transits\TMMT\TOI-2015\CR_TEST_ALL''')
regex = "*.fit"
files = glob.glob(os.path.join(FOLDERNAME,regex))

# %%
files
# Out:
# ['C:\\Users\\Marissa\\Desktop\\Research\\Transits\\TMMT\\TOI-2015\\CR_TEST_ALL\\l20210218-072021-TOI-2015-I.fit',
#  'C:\\Users\\Marissa\\Desktop\\Research\\Transits\\TMMT\\TOI-2015\\CR_TEST_ALL\\l20210218-072240-TOI-2015-I.fit',
#  'C:\\Users\\Marissa\\Desktop\\Research\\Transits\\TMMT\\TOI-2015\\CR_TEST_ALL\\l20210218-072456-TOI-2015-I.fit',
#  'C:\\Users\\Marissa\\Desktop\\Research\\Transits\\TMMT\\TOI-2015\\CR_TEST_ALL\\l20210218-072712-TOI-2015-I.fit',
#  'C:\\Users\\Marissa\\Desktop\\Research\\Transits\\TMMT\\TOI-2015\\CR_TEST_ALL\\l20210218-072927-TOI-2015-I.fit',
#  'C:\\Users\\Marissa\\Desktop\\Research\\Transits\\TMMT\\TOI-2015\\CR_TEST_ALL\\l20210218-073143-TOI-2015-I.fit',
#  'C:\\Users\\Marissa\\Desktop\\Research\\Transits\\TMMT\\TOI-2015\\CR_TEST_ALL\\l20210218-073358-TOI-2015-I.fit',
#  'C:\\Users\\Marissa\\Desktop\\Research\\Transits\\TMMT\\TOI-2015\\CR_TEST_ALL\\l20210218-073614-TOI-2015-I.fit',
#  'C:\\Users\\Marissa\\Desktop\\Research\\Transits\\TMMT\\TOI-2015\\CR_TEST_ALL\\l20210218-073829-TOI-2015-I.fit',
#  'C:\\Users\\Marissa\\Desktop\\Research\\Transits\\TMMT\\TOI-2015\\CR_TEST_ALL\\l20210218-074044-TOI-2015-I.fit',
#  'C:\\Users\\Marissa\\Desktop\\Research\\Transits\\TMMT\\TOI-2015\\CR_TEST_ALL\\l20210218-074300-TOI-2015-I.fit',
#  'C:\\Users\\Marissa\\Desktop\\Research\\Transits\\TMMT\\TOI-2015\\CR_TEST_ALL\\l20210218-074515-TOI-2015-I.fit',
#  'C:\\Users\\Marissa\\Desktop\\Research\\Transits\\TMMT\\TOI-2015\\CR_TEST_ALL\\l20210218-074731-TOI-2015-I.fit',
#  'C:\\Users\\Marissa\\Desktop\\Research\\Transits\\TMMT\\TOI-2015\\CR_TEST_ALL\\l20210218-074946-TOI-2015-I.fit',
#  'C:\\Users\\Marissa\\Desktop\\Research\\Transits\\TMMT\\TOI-2015\\CR_TEST_ALL\\l20210218-075202-TOI-2015-I.fit',
#  'C:\\Users\\Marissa\\Desktop\\Research\\Transits\\TMMT\\TOI-2015\\CR_TEST_ALL\\l20210218-075417-TOI-2015-I.fit',
#  'C:\\Users\\Marissa\\Desktop\\Research\\Transits\\TMMT\\TOI-2015\\CR_TEST_ALL\\l20210218-075633-TOI-2015-I.fit',
#  'C:\\Users\\Marissa\\Desktop\\Research\\Transits\\TMMT\\TOI-2015\\CR_TEST_ALL\\l20210218-075848-TOI-2015-I.fit',
#  'C:\\Users\\Marissa\\Desktop\\Research\\Transits\\TMMT\\TOI-2015\\CR_TEST_ALL\\l20210218-080104-TOI-2015-I.fit',
#  'C:\\Users\\Marissa\\Desktop\\Research\\Transits\\TMMT\\TOI-2015\\CR_TEST_ALL\\l20210218-080320-TOI-2015-I.fit',
#  'C:\\Users\\Marissa\\Desktop\\Research\\Transits\\TMMT\\TOI-2015\\CR_TEST_ALL\\l20210218-080535-TOI-2015-I.fit',
#  'C:\\Users\\Marissa\\Desktop\\Research\\Transits\\TMMT\\TOI-2015\\CR_TEST_ALL\\l20210218-080750-TOI-2015-I.fit',
#  'C:\\Users\\Marissa\\Desktop\\Research\\Transits\\TMMT\\TOI-2015\\CR_TEST_ALL\\l20210218-081006-TOI-2015-I.fit',
#  'C:\\Users\\Marissa\\Desktop\\Research\\Transits\\TMMT\\TOI-2015\\CR_TEST_ALL\\l20210218-081221-TOI-2015-I.fit',
#  'C:\\Users\\Marissa\\Desktop\\Research\\Transits\\TMMT\\TOI-2015\\CR_TEST_ALL\\l20210218-081438-TOI-2015-I.fit',
#  'C:\\Users\\Marissa\\Desktop\\Research\\Transits\\TMMT\\TOI-2015\\CR_TEST_ALL\\l20210218-081654-TOI-2015-I.fit',
#  'C:\\Users\\Marissa\\Desktop\\Research\\Transits\\TMMT\\TOI-2015\\CR_TEST_ALL\\l20210218-081924-TOI-2015-I.fit',
#  'C:\\Users\\Marissa\\Desktop\\Research\\Transits\\TMMT\\TOI-2015\\CR_TEST_ALL\\l20210218-082139-TOI-2015-I.fit',
#  'C:\\Users\\Marissa\\Desktop\\Research\\Transits\\TMMT\\TOI-2015\\CR_TEST_ALL\\l20210218-082354-TOI-2015-I.fit',
#  'C:\\Users\\Marissa\\Desktop\\Research\\Transits\\TMMT\\TOI-2015\\CR_TEST_ALL\\l20210218-082608-TOI-2015-I.fit',
#  'C:\\Users\\Marissa\\Desktop\\Research\\Transits\\TMMT\\TOI-2015\\CR_TEST_ALL\\l20210218-082823-TOI-2015-I.fit',
#  'C:\\Users\\Marissa\\Desktop\\Research\\Transits\\TMMT\\TOI-2015\\CR_TEST_ALL\\l20210218-083038-TOI-2015-I.fit',
#  'C:\\Users\\Marissa\\Desktop\\Research\\Transits\\TMMT\\TOI-2015\\CR_TEST_ALL\\l20210218-083253-TOI-2015-I.fit',
#  'C:\\Users\\Marissa\\Desktop\\Research\\Transits\\TMMT\\TOI-2015\\CR_TEST_ALL\\l20210218-083513-TOI-2015-I.fit',
#  'C:\\Users\\Marissa\\Desktop\\Research\\Transits\\TMMT\\TOI-2015\\CR_TEST_ALL\\l20210218-083728-TOI-2015-I.fit',
#  'C:\\Users\\Marissa\\Desktop\\Research\\Transits\\TMMT\\TOI-2015\\CR_TEST_ALL\\l20210218-083944-TOI-2015-I.fit',
#  'C:\\Users\\Marissa\\Desktop\\Research\\Transits\\TMMT\\TOI-2015\\CR_TEST_ALL\\l20210218-084200-TOI-2015-I.fit',
#  'C:\\Users\\Marissa\\Desktop\\Research\\Transits\\TMMT\\TOI-2015\\CR_TEST_ALL\\l20210218-084416-TOI-2015-I.fit',
#  'C:\\Users\\Marissa\\Desktop\\Research\\Transits\\TMMT\\TOI-2015\\CR_TEST_ALL\\l20210218-084631-TOI-2015-I.fit',
#  'C:\\Users\\Marissa\\Desktop\\Research\\Transits\\TMMT\\TOI-2015\\CR_TEST_ALL\\l20210218-084846-TOI-2015-I.fit',
#  'C:\\Users\\Marissa\\Desktop\\Research\\Transits\\TMMT\\TOI-2015\\CR_TEST_ALL\\l20210218-085102-TOI-2015-I.fit',
#  'C:\\Users\\Marissa\\Desktop\\Research\\Transits\\TMMT\\TOI-2015\\CR_TEST_ALL\\l20210218-085317-TOI-2015-I.fit',
#  'C:\\Users\\Marissa\\Desktop\\Research\\Transits\\TMMT\\TOI-2015\\CR_TEST_ALL\\l20210218-085533-TOI-2015-I.fit',
#  'C:\\Users\\Marissa\\Desktop\\Research\\Transits\\TMMT\\TOI-2015\\CR_TEST_ALL\\l20210218-085748-TOI-2015-I.fit',
#  'C:\\Users\\Marissa\\Desktop\\Research\\Transits\\TMMT\\TOI-2015\\CR_TEST_ALL\\l20210218-090003-TOI-2015-I.fit',
#  'C:\\Users\\Marissa\\Desktop\\Research\\Transits\\TMMT\\TOI-2015\\CR_TEST_ALL\\l20210218-090219-TOI-2015-I.fit',
#  'C:\\Users\\Marissa\\Desktop\\Research\\Transits\\TMMT\\TOI-2015\\CR_TEST_ALL\\l20210218-090435-TOI-2015-I.fit',
#  'C:\\Users\\Marissa\\Desktop\\Research\\Transits\\TMMT\\TOI-2015\\CR_TEST_ALL\\l20210218-090650-TOI-2015-I.fit',
#  'C:\\Users\\Marissa\\Desktop\\Research\\Transits\\TMMT\\TOI-2015\\CR_TEST_ALL\\l20210218-090905-TOI-2015-I.fit',
#  'C:\\Users\\Marissa\\Desktop\\Research\\Transits\\TMMT\\TOI-2015\\CR_TEST_ALL\\l20210218-091121-TOI-2015-I.fit',
#  'C:\\Users\\Marissa\\Desktop\\Research\\Transits\\TMMT\\TOI-2015\\CR_TEST_ALL\\l20210218-091336-TOI-2015-I.fit',
#  'C:\\Users\\Marissa\\Desktop\\Research\\Transits\\TMMT\\TOI-2015\\CR_TEST_ALL\\l20210218-091552-TOI-2015-I.fit',
#  'C:\\Users\\Marissa\\Desktop\\Research\\Transits\\TMMT\\TOI-2015\\CR_TEST_ALL\\l20210218-091807-TOI-2015-I.fit',
#  'C:\\Users\\Marissa\\Desktop\\Research\\Transits\\TMMT\\TOI-2015\\CR_TEST_ALL\\l20210218-092023-TOI-2015-I.fit',
#  'C:\\Users\\Marissa\\Desktop\\Research\\Transits\\TMMT\\TOI-2015\\CR_TEST_ALL\\l20210218-092238-TOI-2015-I.fit',
#  'C:\\Users\\Marissa\\Desktop\\Research\\Transits\\TMMT\\TOI-2015\\CR_TEST_ALL\\l20210218-092453-TOI-2015-I.fit',
#  'C:\\Users\\Marissa\\Desktop\\Research\\Transits\\TMMT\\TOI-2015\\CR_TEST_ALL\\l20210218-092709-TOI-2015-I.fit',
#  'C:\\Users\\Marissa\\Desktop\\Research\\Transits\\TMMT\\TOI-2015\\CR_TEST_ALL\\l20210218-092925-TOI-2015-I.fit',
#  'C:\\Users\\Marissa\\Desktop\\Research\\Transits\\TMMT\\TOI-2015\\CR_TEST_ALL\\l20210218-093140-TOI-2015-I.fit',
#  'C:\\Users\\Marissa\\Desktop\\Research\\Transits\\TMMT\\TOI-2015\\CR_TEST_ALL\\l20210218-093356-TOI-2015-I.fit',
#  'C:\\Users\\Marissa\\Desktop\\Research\\Transits\\TMMT\\TOI-2015\\CR_TEST_ALL\\l20210218-093611-TOI-2015-I.fit',
#  'C:\\Users\\Marissa\\Desktop\\Research\\Transits\\TMMT\\TOI-2015\\CR_TEST_ALL\\l20210218-093826-TOI-2015-I.fit']

# %% [markdown]
# # Loop through all test files and clean
#
# - This saves the files in a 0_CLEANED subdirectory in the FOLDERNAME
# - appends a *_cleaned* to the filenames

# %%
psffwhms = [2]
psfsizes = [2]


#rows = ['{}'.format(row) for row in ['Target', 'Reference']]
cols = ['{}'.format(col) for col in ['Cleaned', 'Removed']]

for k in psffwhms:
    for j in psfsizes:
        print("k ="+str(k))
        print("j ="+str(j))
        for i, f in enumerate(files):
            print(i,f)
            fimg = FitsImage(f)
            data_uncleaned=np.copy(fimg.data)
            fimg.remove_cosmics(save_cleaned=True,
                                    gain=1, #gain needs to be changed in 4 locations for filenames
                                    sepmed=True,
                                    overwrite=True,
                                    psffwhm=k,
                                    psfsize=j,
                                    save_suffix='_delta_cleaned_gain_1_sepmed_T_psffwhm_'+str(k)+'_psfsize_'+str(j),
                                    savefolder=os.path.join(FOLDERNAME,'0_CLEANED_SYSTEMATIC_TESTS/'))
            data_cleaned = fimg.cosmics_cleaned_data
            data_delta = data_uncleaned-data_cleaned
            
            #Calculate the mean, median, std of the cleaned data set

            mean, median, std = sigma_clipped_stats(data_cleaned)
            print((mean, median, std))

            #Calculate the mean, median, std of the delta data set

            mean_delta, median_delta, std_delta = sigma_clipped_stats(data_delta)
            print((mean_delta, median_delta, std_delta))

            #Create a mask for the cross hair shape on ARCTIC 
            mask = np.zeros(data_cleaned.shape, dtype=bool)
            mask[500:530,0:2000] = True
            mask[0:2000,510:540] = True
            #Subtract the background and use DAOStarFinder to find the stars in the cleaned image

            daofind = DAOStarFinder(fwhm=2, threshold=5.*std)          
            sources = daofind(data_cleaned - median, mask=mask)
            for col in sources.colnames:
                sources[col].info.format = '%.8g'
            print('There are '+str(len(sources)) + ' stars detected in this FOV.')
            #print(sources)  
            positions = np.transpose((sources['xcentroid'], sources['ycentroid']))
            apertures = CircularAperture(positions, r=6.)
            annulus_aperture = CircularAnnulus(positions, r_in=10, r_out=20)

            #Subtract the background and use DAOStarFinder to find the charged particles from astroscrappy to show the removed points in the image

            daofind_CR = DAOStarFinder(fwhm=1.5, threshold=5.*std_delta)          
            sources_CR = daofind_CR(data_delta - median_delta, mask=mask)
            for col in sources_CR.colnames:
                sources_CR[col].info.format = '%.8g'
            print('There are '+str(len(sources_CR)) + ' charged particles detected in this FOV.') 
            positions_CR = np.transpose((sources_CR['xcentroid'], sources_CR['ycentroid']))
            apertures_CR = CircularAperture(positions_CR, r=5.)

            #Plot the FOV with photometric aperture and CR/charged particles marked

            norm = ImageNormalize(stretch=SqrtStretch())
            fig, ax = plt.subplots(ncols=1,nrows=1)
            plt.imshow(data_cleaned, cmap='viridis', origin='lower', norm=norm, interpolation='nearest')
            apertures.plot(color='white', lw=1.5, alpha=0.5, label='Photometric Aperture') 
            apertures_CR.plot(color='red', lw=1.5, alpha=0.5, label='Charged Particle')  
            annulus_aperture.plot(color='blue', lw=1.5, alpha=0.5, label='Background Annulus')
            plt.title('20210218, TOI-2015, TMMT')
            plt.xlabel('Pixels')
            plt.ylabel('Pixels')
            white_patch =mpatches.Patch(color='white', label = 'Photometric Aperture')
            blue_patch =mpatches.Patch(color='blue', label = 'Background Annulus')
            red_patch =mpatches.Patch(color='red', label = 'Charged Particle')
            plt.legend(loc = 'upper left', handles=[white_patch, blue_patch, red_patch]) 
            fig.suptitle('File:'+ str(''.join(re.findall("I20210218-.(\d+).-TOI-2015-I.fits",files[i])))+', PSFFWHM='+str(k)+', PSFSIZE='+str(j) + ', gain=1') #MUST CHANGE THE REGEX OF FILENAME IF YOU WANT IT LABELLED CORRECTLY
            fig.savefig(r'''C:\Users\Marissa\Desktop\Research\Transits\TMMT\TOI-2015\CR_TEST_ALL\0_CLEANED_SYSTEMATIC_TESTS\UT20210331_cleaned_gain_1_sepmed_T_psffwhm_'''+str(k)+'_psfsize_'+str(j)+'_multiplot_'+str(''.join(re.findall("I20210218-.(\d+).-TOI-2015-I.fits",files[i])))+'.png',dpi=200) #MUST CHANGE THE REGEX OF FILENAME IF YOU WANT IT SAVED CORRECTLY
            plt.close(fig)


            #plot the cleaned and delta for target star
            fig, axx = plt.subplots(ncols=2,nrows=1)
            for ax, col in zip(axx, cols):
                ax.set_xlabel(col, rotation=0, size='large')
            axx.flatten()[0].imshow(data_cleaned[0:2000,0:2000])
            axx.flatten()[1].imshow(data_delta[0:2000,0:2000])
            #axx.flatten()[2].imshow(data_cleaned[0:2000,0:2000])
            #axx.flatten()[3].imshow(data_delta[0:2000,0:2000])
            fig.suptitle('File:'+ str(''.join(re.findall("I20210218-(\d+)-TOI-2015-I.fits",files[i])))+', PSFFWHM='+str(k)+', PSFSIZE='+str(j) + ', gain=1') #MUST CHANGE THE REGEX OF FILENAME IF YOU WANT IT LABELLED CORRECTLY
            fig.savefig(r'''C:\Users\Marissa\Desktop\Research\Transits\TMMT\TOI-2015\CR_TEST_ALL\0_CLEANED_SYSTEMATIC_TESTS\UT20210218_cleaned_gain_1_sepmed_T_psffwhm_'''+str(k)+'_psfsize_'+str(j)+'_'+str(''.join(re.findall("I20210218-(\d+)-TOI-2015-I.fits",files[i])))+'.png',dpi=200) #MUST CHANGE THE REGEX OF FILENAME IF YOU WANT IT SAVED CORRECTLY
            plt.close(fig)
# Out:
# ograms\Python\Python38\lib\site-packages\photutils\detection\daofinder.py:531: RuntimeWarning: divide by zero encountered in double_scalars
#   return ((self.conv_peak / self.cutout.threshold_eff)
# There are 118 charged particles detected in this FOV.
# 49 C:\Users\Marissa\Desktop\Research\Transits\TMMT\TOI-2015\CR_TEST_ALL\l20210218-091121-TOI-2015-I.fit
# Cleaning cosmic rays
# <ipython-input-4-7b2efe561d8e>:44: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   self.cosmics_mask, self.cosmics_cleaned_data = astroscrappy.detect_cosmics(self.data,
# Starting 4 L.A.Cosmic iterations
# Iteration 1:
# 3151 cosmic pixels this iteration
# Iteration 2:
# 1446 cosmic pixels this iteration
# Iteration 3:
# 1385 cosmic pixels this iteration
# Iteration 4:
# 1385 cosmic pixels this iteration
# C:\Users\Marissa\Desktop\Research\Transits\TMMT\TOI-2015\CR_TEST_ALL\0_CLEANED_SYSTEMATIC_TESTS/ already exists. Skipping
# Saved to C:\Users\Marissa\Desktop\Research\Transits\TMMT\TOI-2015\CR_TEST_ALL\0_CLEANED_SYSTEMATIC_TESTS/\l20210218-091121-TOI-2015-I_delta_cleaned_gain_1_sepmed_T_psffwhm_2_psfsize_2.fit
# (254.6059, 254.43716, 17.698175)
# (0.0, 0.0, 0.0)
# There are 260 stars detected in this FOV.
# C:\Users\Marissa\AppData\Local\Programs\Python\Python38\lib\site-packages\photutils\detection\daofinder.py:531: RuntimeWarning: divide by zero encountered in double_scalars
#   return ((self.conv_peak / self.cutout.threshold_eff)
# There are 108 charged particles detected in this FOV.
# 50 C:\Users\Marissa\Desktop\Research\Transits\TMMT\TOI-2015\CR_TEST_ALL\l20210218-091336-TOI-2015-I.fit
# Cleaning cosmic rays
# <ipython-input-4-7b2efe561d8e>:44: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   self.cosmics_mask, self.cosmics_cleaned_data = astroscrappy.detect_cosmics(self.data,
# Starting 4 L.A.Cosmic iterations
# Iteration 1:
# 3187 cosmic pixels this iteration
# Iteration 2:
# 1423 cosmic pixels this iteration
# Iteration 3:
# 1382 cosmic pixels this iteration
# Iteration 4:
# 1379 cosmic pixels this iteration
# C:\Users\Marissa\Desktop\Research\Transits\TMMT\TOI-2015\CR_TEST_ALL\0_CLEANED_SYSTEMATIC_TESTS/ already exists. Skipping
# Saved to C:\Users\Marissa\Desktop\Research\Transits\TMMT\TOI-2015\CR_TEST_ALL\0_CLEANED_SYSTEMATIC_TESTS/\l20210218-091336-TOI-2015-I_delta_cleaned_gain_1_sepmed_T_psffwhm_2_psfsize_2.fit
# (254.43022, 254.27037, 17.631548)
# (0.0, 0.0, 0.0)
# There are 472 stars detected in this FOV.
# C:\Users\Marissa\AppData\Local\Programs\Python\Python38\lib\site-packages\photutils\detection\daofinder.py:531: RuntimeWarning: divide by zero encountered in double_scalars
#   return ((self.conv_peak / self.cutout.threshold_eff)
# There are 122 charged particles detected in this FOV.
# 51 C:\Users\Marissa\Desktop\Research\Transits\TMMT\TOI-2015\CR_TEST_ALL\l20210218-091552-TOI-2015-I.fit
# Cleaning cosmic rays
# <ipython-input-4-7b2efe561d8e>:44: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   self.cosmics_mask, self.cosmics_cleaned_data = astroscrappy.detect_cosmics(self.data,
# Starting 4 L.A.Cosmic iterations
# Iteration 1:
# 3106 cosmic pixels this iteration
# Iteration 2:
# 1416 cosmic pixels this iteration
# Iteration 3:
# 1372 cosmic pixels this iteration
# Iteration 4:
# 1372 cosmic pixels this iteration
# C:\Users\Marissa\Desktop\Research\Transits\TMMT\TOI-2015\CR_TEST_ALL\0_CLEANED_SYSTEMATIC_TESTS/ already exists. Skipping
# Saved to C:\Users\Marissa\Desktop\Research\Transits\TMMT\TOI-2015\CR_TEST_ALL\0_CLEANED_SYSTEMATIC_TESTS/\l20210218-091552-TOI-2015-I_delta_cleaned_gain_1_sepmed_T_psffwhm_2_psfsize_2.fit
# (258.72217, 258.5579, 17.689543)
# (0.0, 0.0, 0.0)
# There are 559 stars detected in this FOV.
# C:\Users\Marissa\AppData\Local\Programs\Python\Python38\lib\site-packages\photutils\detection\daofinder.py:531: RuntimeWarning: divide by zero encountered in double_scalars
#   return ((self.conv_peak / self.cutout.threshold_eff)
# There are 92 charged particles detected in this FOV.
# 52 C:\Users\Marissa\Desktop\Research\Transits\TMMT\TOI-2015\CR_TEST_ALL\l20210218-091807-TOI-2015-I.fit
# Cleaning cosmic rays
# <ipython-input-4-7b2efe561d8e>:44: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   self.cosmics_mask, self.cosmics_cleaned_data = astroscrappy.detect_cosmics(self.data,
# Starting 4 L.A.Cosmic iterations
# Iteration 1:
# 3122 cosmic pixels this iteration
# Iteration 2:
# 1422 cosmic pixels this iteration
# Iteration 3:
# 1357 cosmic pixels this iteration
# Iteration 4:
# 1352 cosmic pixels this iteration
# C:\Users\Marissa\Desktop\Research\Transits\TMMT\TOI-2015\CR_TEST_ALL\0_CLEANED_SYSTEMATIC_TESTS/ already exists. Skipping
# Saved to C:\Users\Marissa\Desktop\Research\Transits\TMMT\TOI-2015\CR_TEST_ALL\0_CLEANED_SYSTEMATIC_TESTS/\l20210218-091807-TOI-2015-I_delta_cleaned_gain_1_sepmed_T_psffwhm_2_psfsize_2.fit
# (271.3141, 271.15543, 17.975521)
# (0.0, 0.0, 0.0)
# There are 668 stars detected in this FOV.
# C:\Users\Marissa\AppData\Local\Programs\Python\Python38\lib\site-packages\photutils\detection\daofinder.py:531: RuntimeWarning: divide by zero encountered in double_scalars
#   return ((self.conv_peak / self.cutout.threshold_eff)
# There are 111 charged particles detected in this FOV.
# 53 C:\Users\Marissa\Desktop\Research\Transits\TMMT\TOI-2015\CR_TEST_ALL\l20210218-092023-TOI-2015-I.fit
# Cleaning cosmic rays
# <ipython-input-4-7b2efe561d8e>:44: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   self.cosmics_mask, self.cosmics_cleaned_data = astroscrappy.detect_cosmics(self.data,
# Starting 4 L.A.Cosmic iterations
# Iteration 1:
# 2953 cosmic pixels this iteration
# Iteration 2:
# 1379 cosmic pixels this iteration
# Iteration 3:
# 1332 cosmic pixels this iteration
# Iteration 4:
# 1332 cosmic pixels this iteration
# C:\Users\Marissa\Desktop\Research\Transits\TMMT\TOI-2015\CR_TEST_ALL\0_CLEANED_SYSTEMATIC_TESTS/ already exists. Skipping
# Saved to C:\Users\Marissa\Desktop\Research\Transits\TMMT\TOI-2015\CR_TEST_ALL\0_CLEANED_SYSTEMATIC_TESTS/\l20210218-092023-TOI-2015-I_delta_cleaned_gain_1_sepmed_T_psffwhm_2_psfsize_2.fit
# (292.44495, 292.24042, 18.343752)
# (0.0, 0.0, 0.0)
# There are 620 stars detected in this FOV.
# C:\Users\Marissa\AppData\Local\Programs\Python\Python38\lib\site-packages\photutils\detection\daofinder.py:531: RuntimeWarning: divide by zero encountered in double_scalars
#   return ((self.conv_peak / self.cutout.threshold_eff)
# There are 104 charged particles detected in this FOV.
# 54 C:\Users\Marissa\Desktop\Research\Transits\TMMT\TOI-2015\CR_TEST_ALL\l20210218-092238-TOI-2015-I.fit
# Cleaning cosmic rays
# <ipython-input-4-7b2efe561d8e>:44: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   self.cosmics_mask, self.cosmics_cleaned_data = astroscrappy.detect_cosmics(self.data,
# Starting 4 L.A.Cosmic iterations
# Iteration 1:
# 2824 cosmic pixels this iteration
# Iteration 2:
# 1324 cosmic pixels this iteration
# Iteration 3:
# 1287 cosmic pixels this iteration
# Iteration 4:
# 1282 cosmic pixels this iteration
# C:\Users\Marissa\Desktop\Research\Transits\TMMT\TOI-2015\CR_TEST_ALL\0_CLEANED_SYSTEMATIC_TESTS/ already exists. Skipping
# Saved to C:\Users\Marissa\Desktop\Research\Transits\TMMT\TOI-2015\CR_TEST_ALL\0_CLEANED_SYSTEMATIC_TESTS/\l20210218-092238-TOI-2015-I_delta_cleaned_gain_1_sepmed_T_psffwhm_2_psfsize_2.fit
# (334.3343, 334.12402, 19.397907)
# (0.0, 0.0, 0.0)
# There are 347 stars detected in this FOV.
# C:\Users\Marissa\AppData\Local\Programs\Python\Python38\lib\site-packages\photutils\detection\daofinder.py:531: RuntimeWarning: divide by zero encountered in double_scalars
#   return ((self.conv_peak / self.cutout.threshold_eff)
# There are 94 charged particles detected in this FOV.
# 55 C:\Users\Marissa\Desktop\Research\Transits\TMMT\TOI-2015\CR_TEST_ALL\l20210218-092453-TOI-2015-I.fit
# Cleaning cosmic rays
# <ipython-input-4-7b2efe561d8e>:44: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   self.cosmics_mask, self.cosmics_cleaned_data = astroscrappy.detect_cosmics(self.data,
# Starting 4 L.A.Cosmic iterations
# Iteration 1:
# 2710 cosmic pixels this iteration
# Iteration 2:
# 1286 cosmic pixels this iteration
# Iteration 3:
# 1224 cosmic pixels this iteration
# Iteration 4:
# 1218 cosmic pixels this iteration
# C:\Users\Marissa\Desktop\Research\Transits\TMMT\TOI-2015\CR_TEST_ALL\0_CLEANED_SYSTEMATIC_TESTS/ already exists. Skipping
# Saved to C:\Users\Marissa\Desktop\Research\Transits\TMMT\TOI-2015\CR_TEST_ALL\0_CLEANED_SYSTEMATIC_TESTS/\l20210218-092453-TOI-2015-I_delta_cleaned_gain_1_sepmed_T_psffwhm_2_psfsize_2.fit
# (408.56494, 408.34988, 21.194794)
# (0.0, 0.0, 0.0)
# There are 403 stars detected in this FOV.
# C:\Users\Marissa\AppData\Local\Programs\Python\Python38\lib\site-packages\photutils\detection\daofinder.py:531: RuntimeWarning: divide by zero encountered in double_scalars
#   return ((self.conv_peak / self.cutout.threshold_eff)
# There are 96 charged particles detected in this FOV.
# 56 C:\Users\Marissa\Desktop\Research\Transits\TMMT\TOI-2015\CR_TEST_ALL\l20210218-092709-TOI-2015-I.fit
# Cleaning cosmic rays
# <ipython-input-4-7b2efe561d8e>:44: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   self.cosmics_mask, self.cosmics_cleaned_data = astroscrappy.detect_cosmics(self.data,
# Starting 4 L.A.Cosmic iterations
# Iteration 1:
# 2478 cosmic pixels this iteration
# Iteration 2:
# 1124 cosmic pixels this iteration
# Iteration 3:
# 1073 cosmic pixels this iteration
# Iteration 4:
# 1070 cosmic pixels this iteration
# C:\Users\Marissa\Desktop\Research\Transits\TMMT\TOI-2015\CR_TEST_ALL\0_CLEANED_SYSTEMATIC_TESTS/ already exists. Skipping
# Saved to C:\Users\Marissa\Desktop\Research\Transits\TMMT\TOI-2015\CR_TEST_ALL\0_CLEANED_SYSTEMATIC_TESTS/\l20210218-092709-TOI-2015-I_delta_cleaned_gain_1_sepmed_T_psffwhm_2_psfsize_2.fit
# (526.3773, 526.1758, 23.680754)
# (0.0, 0.0, 0.0)
# There are 341 stars detected in this FOV.
# C:\Users\Marissa\AppData\Local\Programs\Python\Python38\lib\site-packages\photutils\detection\daofinder.py:531: RuntimeWarning: divide by zero encountered in double_scalars
#   return ((self.conv_peak / self.cutout.threshold_eff)
# There are 81 charged particles detected in this FOV.
# 57 C:\Users\Marissa\Desktop\Research\Transits\TMMT\TOI-2015\CR_TEST_ALL\l20210218-092925-TOI-2015-I.fit
# Cleaning cosmic rays
# <ipython-input-4-7b2efe561d8e>:44: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   self.cosmics_mask, self.cosmics_cleaned_data = astroscrappy.detect_cosmics(self.data,
# Starting 4 L.A.Cosmic iterations
# Iteration 1:
# 2250 cosmic pixels this iteration
# Iteration 2:
# 968 cosmic pixels this iteration
# Iteration 3:
# 933 cosmic pixels this iteration
# Iteration 4:
# 930 cosmic pixels this iteration
# C:\Users\Marissa\Desktop\Research\Transits\TMMT\TOI-2015\CR_TEST_ALL\0_CLEANED_SYSTEMATIC_TESTS/ already exists. Skipping
# Saved to C:\Users\Marissa\Desktop\Research\Transits\TMMT\TOI-2015\CR_TEST_ALL\0_CLEANED_SYSTEMATIC_TESTS/\l20210218-092925-TOI-2015-I_delta_cleaned_gain_1_sepmed_T_psffwhm_2_psfsize_2.fit
# (719.1389, 718.9173, 27.159494)
# (0.0, 0.0, 0.0)
# There are 305 stars detected in this FOV.
# C:\Users\Marissa\AppData\Local\Programs\Python\Python38\lib\site-packages\photutils\detection\daofinder.py:531: RuntimeWarning: divide by zero encountered in double_scalars
#   return ((self.conv_peak / self.cutout.threshold_eff)
# There are 81 charged particles detected in this FOV.
# 58 C:\Users\Marissa\Desktop\Research\Transits\TMMT\TOI-2015\CR_TEST_ALL\l20210218-093140-TOI-2015-I.fit
# Cleaning cosmic rays
# <ipython-input-4-7b2efe561d8e>:44: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   self.cosmics_mask, self.cosmics_cleaned_data = astroscrappy.detect_cosmics(self.data,
# Starting 4 L.A.Cosmic iterations
# Iteration 1:
# 1927 cosmic pixels this iteration
# Iteration 2:
# 795 cosmic pixels this iteration
# Iteration 3:
# 774 cosmic pixels this iteration
# Iteration 4:
# 771 cosmic pixels this iteration
# C:\Users\Marissa\Desktop\Research\Transits\TMMT\TOI-2015\CR_TEST_ALL\0_CLEANED_SYSTEMATIC_TESTS/ already exists. Skipping
# Saved to C:\Users\Marissa\Desktop\Research\Transits\TMMT\TOI-2015\CR_TEST_ALL\0_CLEANED_SYSTEMATIC_TESTS/\l20210218-093140-TOI-2015-I_delta_cleaned_gain_1_sepmed_T_psffwhm_2_psfsize_2.fit
# (1026.9305, 1026.6858, 32.108273)
# (0.0, 0.0, 0.0)
# There are 305 stars detected in this FOV.
# C:\Users\Marissa\AppData\Local\Programs\Python\Python38\lib\site-packages\photutils\detection\daofinder.py:531: RuntimeWarning: divide by zero encountered in double_scalars
#   return ((self.conv_peak / self.cutout.threshold_eff)
# There are 70 charged particles detected in this FOV.
# 59 C:\Users\Marissa\Desktop\Research\Transits\TMMT\TOI-2015\CR_TEST_ALL\l20210218-093356-TOI-2015-I.fit
# Cleaning cosmic rays
# <ipython-input-4-7b2efe561d8e>:44: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   self.cosmics_mask, self.cosmics_cleaned_data = astroscrappy.detect_cosmics(self.data,
# Starting 4 L.A.Cosmic iterations
# Iteration 1:
# 1692 cosmic pixels this iteration
# Iteration 2:
# 673 cosmic pixels this iteration
# Iteration 3:
# 647 cosmic pixels this iteration
# Iteration 4:
# 647 cosmic pixels this iteration
# C:\Users\Marissa\Desktop\Research\Transits\TMMT\TOI-2015\CR_TEST_ALL\0_CLEANED_SYSTEMATIC_TESTS/ already exists. Skipping
# Saved to C:\Users\Marissa\Desktop\Research\Transits\TMMT\TOI-2015\CR_TEST_ALL\0_CLEANED_SYSTEMATIC_TESTS/\l20210218-093356-TOI-2015-I_delta_cleaned_gain_1_sepmed_T_psffwhm_2_psfsize_2.fit
# (1505.2355, 1504.9634, 38.88965)
# (0.0, 0.0, 0.0)
# There are 289 stars detected in this FOV.
# C:\Users\Marissa\AppData\Local\Programs\Python\Python38\lib\site-packages\photutils\detection\daofinder.py:531: RuntimeWarning: divide by zero encountered in double_scalars
#   return ((self.conv_peak / self.cutout.threshold_eff)
# There are 56 charged particles detected in this FOV.
# 60 C:\Users\Marissa\Desktop\Research\Transits\TMMT\TOI-2015\CR_TEST_ALL\l20210218-093611-TOI-2015-I.fit
# Cleaning cosmic rays
# <ipython-input-4-7b2efe561d8e>:44: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   self.cosmics_mask, self.cosmics_cleaned_data = astroscrappy.detect_cosmics(self.data,
# Starting 4 L.A.Cosmic iterations
# Iteration 1:
# 1371 cosmic pixels this iteration
# Iteration 2:
# 421 cosmic pixels this iteration
# Iteration 3:
# 410 cosmic pixels this iteration
# Iteration 4:
# 408 cosmic pixels this iteration
# C:\Users\Marissa\Desktop\Research\Transits\TMMT\TOI-2015\CR_TEST_ALL\0_CLEANED_SYSTEMATIC_TESTS/ already exists. Skipping
# Saved to C:\Users\Marissa\Desktop\Research\Transits\TMMT\TOI-2015\CR_TEST_ALL\0_CLEANED_SYSTEMATIC_TESTS/\l20210218-093611-TOI-2015-I_delta_cleaned_gain_1_sepmed_T_psffwhm_2_psfsize_2.fit
# (2227.1167, 2226.7908, 47.58379)
# (0.0, 0.0, 0.0)
# There are 284 stars detected in this FOV.
# C:\Users\Marissa\AppData\Local\Programs\Python\Python38\lib\site-packages\photutils\detection\daofinder.py:531: RuntimeWarning: divide by zero encountered in double_scalars
#   return ((self.conv_peak / self.cutout.threshold_eff)
# There are 46 charged particles detected in this FOV.
# 61 C:\Users\Marissa\Desktop\Research\Transits\TMMT\TOI-2015\CR_TEST_ALL\l20210218-093826-TOI-2015-I.fit
# Cleaning cosmic rays
# <ipython-input-4-7b2efe561d8e>:44: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   self.cosmics_mask, self.cosmics_cleaned_data = astroscrappy.detect_cosmics(self.data,
# Starting 4 L.A.Cosmic iterations
# Iteration 1:
# 1157 cosmic pixels this iteration
# Iteration 2:
# 336 cosmic pixels this iteration
# Iteration 3:
# 324 cosmic pixels this iteration
# Iteration 4:
# 324 cosmic pixels this iteration
# C:\Users\Marissa\Desktop\Research\Transits\TMMT\TOI-2015\CR_TEST_ALL\0_CLEANED_SYSTEMATIC_TESTS/ already exists. Skipping
# Saved to C:\Users\Marissa\Desktop\Research\Transits\TMMT\TOI-2015\CR_TEST_ALL\0_CLEANED_SYSTEMATIC_TESTS/\l20210218-093826-TOI-2015-I_delta_cleaned_gain_1_sepmed_T_psffwhm_2_psfsize_2.fit
# (3287.8665, 3287.564, 58.560184)
# (0.0, 0.0, 0.0)
# There are 186 stars detected in this FOV.
# C:\Users\Marissa\AppData\Local\Programs\Python\Python38\lib\site-packages\photutils\detection\daofinder.py:531: RuntimeWarning: divide by zero encountered in double_scalars
#   return ((self.conv_peak / self.cutout.threshold_eff)
# There are 47 charged particles detected in this FOV.

# %%
#Find cleaned files

FOLDERNAME2 = os.path.abspath(r'''C:\Users\Marissa\Desktop\Research\Transits\ARCTIC\20210331_TIC-207x\CR_TEST\0_CLEANED_SYSTEMATIC_TESTS''')
regex = "*.fits"
files2 = glob.glob(os.path.join(FOLDERNAME2,regex))

# %%
files2
# Out:
# ['C:\\Users\\Marissa\\Desktop\\Research\\Transits\\ARCTIC\\20210331_TIC-207x\\CR_TEST\\0_CLEANED_SYSTEMATIC_TESTS\\TIC-207-diffuser-i.0177_delta_cleaned_gain_1_sepmed_T_psffwhm_2_psfsize_2.fits',
#  'C:\\Users\\Marissa\\Desktop\\Research\\Transits\\ARCTIC\\20210331_TIC-207x\\CR_TEST\\0_CLEANED_SYSTEMATIC_TESTS\\TIC-207-diffuser-i.0523_delta_cleaned_gain_1_sepmed_T_psffwhm_2_psfsize_2.fits']

# %%
for a in enumerate(files2):
    print(a)
    hdu = fits.open(a)[0]
    wcs = WCS(hdu.header)
    sky = w.pixel_to_world()
# Out:
# (0, 'C:\\Users\\Marissa\\Desktop\\Research\\Transits\\ARCTIC\\20210331_TIC-207x\\CR_TEST\\0_CLEANED_SYSTEMATIC_TESTS\\TIC-207-diffuser-i.0177_delta_cleaned_gain_1_sepmed_T_psffwhm_2_psfsize_2.fits')
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-94-2fb0b2201efa> in <module>
#       1 for a in enumerate(files2):
#       2     print(a)
# ----> 3     hdu = fits.open(a)[0]
#       4     wcs = WCS(hdu.header)
#       5     sky = w.pixel_to_world()
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\astropy\io\fits\hdu\hdulist.py in fitsopen(name, mode, memmap, save_backup, cache, lazy_load_hdus, **kwargs)
#     162         raise ValueError(f'Empty filename: {name!r}')
#     163
# --> 164     return HDUList.fromfile(name, mode, memmap, save_backup, cache,
#     165                             lazy_load_hdus, **kwargs)
#     166
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\astropy\io\fits\hdu\hdulist.py in fromfile(cls, fileobj, mode, memmap, save_backup, cache, lazy_load_hdus, **kwargs)
#     399         """
#     400
# --> 401         return cls._readfrom(fileobj=fileobj, mode=mode, memmap=memmap,
#     402                              save_backup=save_backup, cache=cache,
#     403                              lazy_load_hdus=lazy_load_hdus, **kwargs)
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\astropy\io\fits\hdu\hdulist.py in _readfrom(cls, fileobj, data, mode, memmap, cache, lazy_load_hdus, **kwargs)
#    1050             if not isinstance(fileobj, _File):
#    1051                 # instantiate a FITS file object (ffo)
# -> 1052                 fileobj = _File(fileobj, mode=mode, memmap=memmap, cache=cache)
#    1053             # The Astropy mode is determined by the _File initializer if the
#    1054             # supplied mode was None
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\astropy\utils\decorators.py in wrapper(*args, **kwargs)
#     533                     warnings.warn(message, warning_type, stacklevel=2)
#     534
# --> 535             return function(*args, **kwargs)
#     536
#     537         return wrapper
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\astropy\io\fits\file.py in __init__(self, fileobj, mode, memmap, overwrite, cache)
#     175             self._open_filename(fileobj, mode, overwrite)
#     176         else:
# --> 177             self._open_filelike(fileobj, mode, overwrite)
#     178
#     179         self.fileobj_mode = fileobj_mode(self._file)
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\astropy\io\fits\file.py in _open_filelike(self, fileobj, mode, overwrite)
#     539         if (self.mode in ('update', 'append', 'ostream') and
#     540                 not hasattr(self._file, 'write')):
# --> 541             raise OSError("File-like object does not have a 'write' "
#     542                           "method, required for mode '{}'.".format(self.mode))
#     543
#
# OSError: File-like object does not have a 'write' method, required for mode 'ostream'.
